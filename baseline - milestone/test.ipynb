# %%
import torch
import pandas as pd
from transformers import BertForQuestionAnswering
from transformers import BertTokenizer, BertTokenizerFast

# %%
model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
tokenizer = BertTokenizerFast.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

# %%
dataset = pd.read_csv("../dataset.csv")

# %%
len(dataset)
# Out:
# 50

# %%
dataset
# Out:
#                                              Question  \
# 0   What type of contract is the Lakers Practice F...
# 1                         What is the project number?
# 2               Who is the architect of this project?
# 3      What is the telephone number of the Architect?
# 4               What is the address of the Architect?
# 5   What type of welding electrodes are used for r...
# 6   What are the specificaitons for cold-formed st...
# 7   What are the specifcations for chain-link fenc...
# 8   What particulates need to be prevented of bein...
# 9   What should be included in the Completed Coord...
# 10  What is included in the final coordination model?
# 11           What software is used for the BIM Model?
# 12  What is the purpose of the weekly BIM Developm...
# 13  Whose responsibility is it to perform tests an...
# 14  How much advance notice should the contractor ...
# 15  What should the contractor do when quality-con...
# ...

# %%
dataset['answer'] = dataset['answer'].replace({'\n': '', '  ': ' '}, regex=True)
dataset['Paragraph'] = dataset['Paragraph'].replace({'\n': '', '  ': ' '}, regex=True)

# %%
dataset.to_csv('../dataset.csv', index=False)

# %%
filtered_df = dataset[~dataset.apply(lambda row: row['answer'] in row['Paragraph'], axis=1)]

# %%
filtered_df
# Out:
# Empty DataFrame
# Columns: [Question, Paragraph, Page, answer, bm25_k=3_pages, bm25_mugi_k=3_pages, cosine_similarity_k=3]
# Index: []

# %%
filtered_df.to_csv('/Users/Thoma/Documents/Github/CS224n_project/baseline - milestone/test_filtered.csv', index=True)

# %%
dataset = pd.read_csv("/Users/Thoma/Documents/Github/CS224n_project/baseline - milestone/test_filtered.csv")

# %%
dataset
# Out:
#     Unnamed: 0                                           Question  \
# 0            5  What type of welding electrodes are used for r...
# 1            7  What are the specifcations for chain-link fenc...
# 2            8  What particulates need to be prevented of bein...
# 3           12  What is the purpose of the weekly BIM Developm...
# 4           13  Whose responsibility is it to perform tests an...
# 5           14  How much advance notice should the contractor ...
# 6           15  What should the contractor do when quality-con...
# 7           16  If directed by the Authorities Having Jurisdic...
# 8           17  For Storm Water Pollution Prevention what docu...
# 9           18  What does the SWPPP Praticioner need to measur...
# 10          19  How should loose stockpiled construction mater...
# 11          21        How should carboard and boxes be recycled?
# 12          22     How should polystyrene packaging be recycled?
# ...
